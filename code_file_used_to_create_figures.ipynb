# %% [markdown]
# # *Strain vs. time plot for all experiments*
# The strain values are compute as mentioned in the methodology section for each experiment and is plotted against time.

# %%
import matplotlib.pyplot as plt

# Data for selected experiments representing both landlside/rockslide model and glacial model
experiments = {
    "EXP1": ([0, 105, 110, 131, 135, 156, 159, 183, 187, 217],
             [0, 0, -0.0195, -0.026, -0.1089, -0.16, -0.2, -0.21, -0.32, -0.36]),
    "EXP6": ([0, 37, 41, 65, 114, 117, 138, 145, 148, 165, 176, 179, 205],
             [0, 0, 0.007, 0.024, 0.024, 0.08, 0.14, 0.28, 0.42, 0.45, 0.46, 0.29, 0.12]),
    "EXP15": ([0, 5, 11, 24, 44, 55, 60],
              [0, 0.2678571429, 0.4464285714, 0.5607142857, 0.6785714286, 0.7071428571, 0.7071428571]),
    "EXP16": ([0, 4, 10, 24, 44, 60],
              [0, 0.1964285714, 0.2857142857, 0.4285714286, 0.5178571429, 0.5178571429])
}

#Figure 1: EXP1 and EXP6
plt.figure(figsize=(7, 5))
for exp in ["EXP1", "EXP6"]:
    time, strain = experiments[exp]
    plt.plot(time, strain, marker='o', label=exp)

plt.xlabel("Time (s)", fontweight='bold', fontsize=14)
plt.ylabel("Strain (ε)", fontweight='bold', fontsize=14)
plt.title('Strain vs Time Graph - Landslide/Rockslide Model', fontweight='bold', fontsize=16)
plt.legend(loc='upper left', prop={'weight': 'bold', 'size': 12})  # Legend
plt.xticks(fontweight='bold', fontsize=12)  # Bold x-axis ticks
plt.yticks(fontweight='bold', fontsize=12)  # Bold y-axis ticks
plt.tight_layout()
plt.savefig("exp1&6_strain_time.png")
plt.show()

# Figure 2: EXP15 and EXP16
plt.figure(figsize=(7, 5))
for exp in ["EXP15", "EXP16"]:
    time, strain = experiments[exp]
    plt.plot(time, strain, marker='o', label=exp)

plt.xlabel("Time (mins)", fontweight='bold', fontsize=14)
plt.ylabel("Strain (ε)", fontweight='bold', fontsize=14)
plt.title('Strain vs Time Graph - Glacial Model', fontweight='bold', fontsize=16)
plt.legend(prop={'weight': 'bold', 'size': 12})  # Legend
plt.xticks(fontweight='bold', fontsize=12)  # Bold x-axis ticks
plt.yticks(fontweight='bold', fontsize=12)  # Bold y-axis ticks
plt.tight_layout()
plt.savefig("exp15_16_strain_time.png")
plt.show()

# %% [markdown]
# Strain vs. time plot for all experiments. Figure presented in appendix A

# %%
import matplotlib.pyplot as plt

# Data for each experiment
experiments = {
    "EXP1": ([0, 105, 110, 131, 135, 156, 159, 183, 187, 217],
             [0, 0, -0.0195, -0.026, -0.1089, -0.16, -0.2, -0.21, -0.32, -0.36]),
    "EXP2": ([0, 85, 150, 158, 219, 230, 235, 255, 258, 265],
             [0, 0, -0.011, -0.012, -0.22, -0.23, -0.4, -0.4, -0.55, -0.57]),
    "EXP3": ([0, 48, 60, 76, 80, 84, 109, 113, 136, 141],
             [0, 0, 0.067, 0.09, 0.25, 0.34, 0.36, 0.19, 0.18, 0.05]),
    "EXP4": ([0, 50, 70, 84, 88, 91, 116, 123, 147, 152],
             [0, 0, 0.057, 0.098, 0.29, 0.34, 0.37, 0.17, 0.16, 0.07]),
    "EXP5": ([0, 42, 60, 76, 80, 84, 109, 113, 136, 141],
             [0, 0, 0.067, 0.09, 0.25, 0.34, 0.36, 0.19, 0.18, 0.05]),
    "EXP6": ([0, 37, 41, 65, 114, 117, 138, 145, 148, 165, 176, 179, 205],
             [0, 0, 0.007, 0.024, 0.024, 0.08, 0.14, 0.28, 0.42, 0.45, 0.46, 0.29, 0.12]),
    "EXP7": ([0, 42, 95, 101, 125, 127, 137, 141, 153, 167],
             [0, 0.01, 0.07, 0.19, 0.26, 0.21, 0.2, 0.12, 0.05, -0.01]),
    "EXP8": ([0, 37, 52, 55, 58, 64, 70, 72, 86, 91, 113, 144, 147],
             [0, 0.013, 0.016, 0.05, 0.142, 0.23, 0.2301, 0.31, 0.318, 0.15, 0.044, -0.023, -0.07]),
    "EXP9": ([0, 38, 57, 64, 79, 81, 94, 101, 104, 108, 112],
             [0, 0, 0.054, 0.23, 0.232, 0.57, 0.63, 0.632, 0.56, 0.48, 0.37]),
    "EXP10": ([0, 10, 23, 25, 29, 30.6, 32.6, 33.6, 37.6, 39.6, 50.6],
              [0.01454545455, 0.08727272727, 0.2181818182, 0.2509090909, 0.3490909091,
               0.5272727273, 0.5563636364, 0.4618181818, 0.3236363636, 0.12, 0.07]),
    "EXP11": ([0, 7, 15, 18, 20, 25, 29, 33, 40],
              [0.075, 0.2392857143, 0.3892857143, 0.5107142857, 0.4785714286,
               0.3571428571, 0.1821428571, -0.003571428571, -0.0019]),
    "EXP12": ([0, 15, 29, 35, 42, 47, 56, 59, 66, 74, 78],
              [0, 0.01785714286, 0.125, 0.3571428571, 0.45, 0.5214285714,
               0.47, 0.39, 0.16, 0.06, 0.01]),
    "EXP13": ([0, 8, 23, 31, 35, 37, 40, 45, 50, 52, 55, 61],
              [0.03571428571, 0.1428571429, 0.2785714286, 0.375, 0.4357142857,
               0.4071428571, 0.3214285714, 0.2785714286, 0.2571428571,
               0.2071428571, 0.02857142857, 0.016]),
    "EXP14": ([6, 24, 32, 38, 41, 45, 48, 53, 58],
              [0.03214285714, 0.1321428571, 0.2464285714, 0.3892857143,
               0.4607142857, 0.4821428571, 0.3892857143, 0.2357142857, 0.03571428571]),
    "EXP15": ([0, 5, 11, 24, 44, 55, 60],
              [0, 0.2678571429, 0.4464285714, 0.5607142857,
               0.6785714286, 0.7071428571, 0.7071428571]),
    "EXP16": ([0, 4, 10, 24, 44, 60],
              [0, 0.1964285714, 0.2857142857, 0.4285714286,
               0.5178571429, 0.5178571429])
}

# Font specifications
label_fontsize = 16
title_fontsize = 16
tick_fontsize = 14

# Create 4x4 grid for subplots
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 15))
axes = axes.flatten()

# Plot
for i, (exp_name, (time, strain)) in enumerate(experiments.items()):
    ax = axes[i]
    ax.plot(time, strain, marker='o', color='b', markersize=5)

    # Titles
    ax.set_title(exp_name, fontsize=title_fontsize, fontweight='bold')

    # X and Y labels
    if exp_name in ["EXP15", "EXP16"]:
        ax.set_xlabel("Time (mins)", fontsize=label_fontsize, fontweight='bold')
    else:
        ax.set_xlabel("Time (s)", fontsize=label_fontsize, fontweight='bold')
    ax.set_ylabel("Strain (ε)", fontsize=label_fontsize, fontweight='bold')

    # Grid
    ax.grid(True)

    # Set tick parameters
    ax.tick_params(axis='both', labelsize=tick_fontsize)
    for label in ax.get_xticklabels() + ax.get_yticklabels():
        label.set_fontweight('bold')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# # Strain percentage vs. slope graphs

# %%
#Data
#X values are the slope angles Y values are the strain percentage

#Exp1
Xo1 = [11,15.4,22,24,25,28,31,32,36,41]
Yo1 =[0,0,-0.348837209,-1.930232558,-10.88372093,-19.76744186,-30.23255814,-45.62790698,-58.8372093,-79.81395349]

#Exp2
Xo3 = [7,14,17.5,23.5,30,32,34,36]
Yo3 = [0,0,0,1.219512195,1.463414634,-22.19512195,-36.95121951,-55.92682927]

#exp3
Xc1 = [6,13,16,17,19,22,23,24,28]
Yc1 = [0,7.317073171,21.2195122,33.17073171,25.36585366,21.70731707,15.36585366,1.951219512,6.097560976]

#Exp5
Xc3 = [6.5,9,10.5,14,16,18,19,22,23.5,24.7]
Yc3 = [3.571428571,6.785714286,17.85714286,44.64285714,37.5,24.64285714,20.35714286,20,17.14285714,3.214285714]

#Exp6
Xc4 = [10.5,13.5,17.5,21,26,27,27.7,29.5,31,34]
Yc4 = [0.701754386,3.50877193,5.964912281,14.38596491,28.42105263,42.45614035,45.96491228,48.77192982,27.01754386,11.92982456]

#exp7
Xc5 = [6,8.5,15.5,20,26,28,32.5,33,33.5,40]
Yc5 = [0,1.023890785,8.19112628,19.45392491,35.49488055,21.50170648,20.13651877,12.28668942,5.802047782,-1.365187713]

#exp8
Xc6 = [7,11,14,18.5,21,26,28.5,30,33.8,35.6,38.9]
Yc6 = [1.355932203,1.694915254,5.084745763,14.23728814,23.38983051,31.18644068,31.86440678,15.59322034,4.406779661,-2.372881356,-7.118644068]

#Exp9
Xt1 = [9,15,19.3,20,24.5,26,28]
Yt1 = [5.454545455,23.63636364,57.45454545,63.63636364,58.90909091,48.36363636,37.45454545]

#exp10
Xt2 = [7,10.5,11,13,15,17.5,21,23.5,25]
Yt2 = [1.454545455,8.727272727,21.81818182,25.09090909,52.72727273,55.63636364,46.18181818,32.36363636,12]

#exp11
Xt3 = [8,12,13.5,15.5,17,19,21.5,25.5]
Yt3 = [7.5,23.92857143,38.92857143,51.07142857,47.85714286,35.71428571,18.21428571,-0.357142857]

#exp13
Xt5 = [7.5,12.5,20,22,24,25,26,27,30.5,34]
Yt5 = [3.571428571,14.28571429,27.85714286,37.5,43.57142857,40.71428571,32.14285714,27.85714286,20.71428571,2.857142857]

#Exp14
Xt6 = [8,11.5,18,21,24.5,26,29,31.5,34]
Yt6 = [3.214285714,13.21428571,24.64285714,38.92857143,46.07142857,48.21428571,38.92857143,23.57142857,3.571428571]

# %%
import matplotlib.pyplot as plt

# Create the figure and subplots (3 rows, 2 columns)
fig, axes = plt.subplots(3, 2, figsize=(12, 16))

# Plot for EXP 1, 3, 9
axes[0, 0].plot(Xo1, Yo1, marker="o", ms=4, color='blue', label='EXP 1')
axes[0, 0].plot(Xc1, Yc1, marker="o", ms=4, color='red', label='EXP 3')
axes[0, 0].plot(Xt1, Yt1, marker="o", ms=4, color='teal', label='EXP 9')
axes[0, 0].tick_params(axis='both', which='major', labelsize=12)
for label in axes[0, 0].get_xticklabels() + axes[0, 0].get_yticklabels():
    label.set_fontweight('bold')

# Plot for EXP 1 and 2
axes[0, 1].plot(Xo1, Yo1, marker="o", ms=4, color='blue', label='EXP 1')
axes[0, 1].plot(Xo3, Yo3, marker="o", ms=4, color='orange', label='EXP 2')
axes[0, 1].tick_params(axis='both', which='major', labelsize=12)
for label in axes[0, 1].get_xticklabels() + axes[0, 1].get_yticklabels():
    label.set_fontweight('bold')

# Plot for EXP 3 and 6
axes[1, 0].plot(Xc1, Yc1, marker="o", ms=4, color='red', label='EXP 3')
axes[1, 0].plot(Xc4, Yc4, marker="o", ms=4, color='green', label='EXP 6')
axes[1, 0].tick_params(axis='both', which='major', labelsize=12)
for label in axes[1, 0].get_xticklabels() + axes[1, 0].get_yticklabels():
    label.set_fontweight('bold')

# Plot for EXP 6, 7, 8
axes[1, 1].plot(Xc4, Yc4, marker="o", ms=4, color='green', label='EXP 6')
axes[1, 1].plot(Xc5, Yc5, marker="o", ms=4, color='cyan', label='EXP 7')
axes[1, 1].plot(Xc6, Yc6, marker="o", ms=4, color='purple', label='EXP 8')
axes[1, 1].tick_params(axis='both', which='major', labelsize=12)
for label in axes[1, 1].get_xticklabels() + axes[1, 1].get_yticklabels():
    label.set_fontweight('bold')

# Plot for EXP 9, 10, 11
axes[2, 0].plot(Xt1, Yt1, marker="o", ms=4, color='teal', label='EXP 9')
axes[2, 0].plot(Xt2, Yt2, marker="o", ms=4, color='darkblue', label='EXP 10')
axes[2, 0].plot(Xt3, Yt3, marker="o", ms=4, color='maroon', label='EXP 11')
axes[2, 0].tick_params(axis='both', which='major', labelsize=12)
for label in axes[2, 0].get_xticklabels() + axes[2, 0].get_yticklabels():
    label.set_fontweight('bold')

# Plot for EXP 8, 5, 13, 10
axes[2, 1].plot(Xc3, Yc3, marker="o", ms=4, color='magenta', label='EXP 5')
axes[2, 1].plot(Xc6, Yc6, marker="o", ms=4, color='purple', label='EXP 8')
axes[2, 1].plot(Xt2, Yt2, marker="o", ms=4, color='darkblue', label='EXP 10')
axes[2, 1].plot(Xt5, Yt5, marker="o", ms=4, color='black', label='EXP 13')
axes[2, 1].tick_params(axis='both', which='major', labelsize=12)
for label in axes[2, 1].get_xticklabels() + axes[2, 1].get_yticklabels():
    label.set_fontweight('bold')

# Add overall axis labels for the entire figure
fig.text(0.5, 0.04, 'Slope angle (°)', ha='center', fontsize=13, fontweight='bold')
fig.text(0.06, 0.5, 'Strain (%)', va='center', rotation='vertical', fontsize=13, fontweight='bold')

# Adjust layout for better spacing
plt.tight_layout(rect=[0.05, 0.05, 0.95, 0.95])
plt.show()

# %% [markdown]
# # Graph of Energy vs. moment magnitude
# The enregy released during a marsquake corresponding to the moment magnitude is plotted here. Refer to section 4.2.1.2 for details on energy computation

# %%
import matplotlib.pyplot as plt


magnitudes = [5.5, 5, 4.5, 4, 3.5, 3, 2.5]
energies = [1122018.454, 199526.2315, 35481.33892, 6309.573445,
            1122.018454, 199.5262315, 35.48133892]

# Plot
plt.figure(figsize=(8, 5))
plt.plot(magnitudes, energies, marker='o', linestyle='-', color='teal', linewidth=2, markersize=8)

# Label and title
plt.xlabel('Moment magnitude', fontsize=12)
plt.ylabel('Energy (Joules)', fontsize=12)
#plt.title('Earthquake Magnitude vs Energy Released', fontsize=14, fontweight='bold')

# Grid and ticks
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(magnitudes, fontsize=11)
plt.yticks(fontsize=11)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Shear stress distribution
# The shear stresses are computed using Equation A1 and is plotted for all experiments for the various slopes recorded during each of the experiments

# %%
import matplotlib.pyplot as plt
import numpy as np

#basal shear stress data for each experiment
basal_shear_data = [[107.4670312, 149.566845, 210.989109, 229.0867771, 238.0324159, 264.4239537, 290.0914583, 298.4741886, 331.0717607, 369.5349596],
    [68.63873379, 136.2552581, 169.3645012, 224.587645, 281.6204528, 298.4741886, 314.9646482, 331.0717607],
    [71.67030653, 154.2395375, 188.9938698, 200.4683097, 223.2307081, 256.8563066, 267.9130416, 278.8882504, 321.9074219],
    [83.56019766, 107.2600872, 124.9509045, 142.5561734, 160.0638405, 171.6754729, 200.4683097, 206.1828711, 217.5645032, 245.72141, 265.7081094, 300.5807562],
    [77.61820456, 107.2600872, 124.9509045, 165.8759664, 188.9938698, 211.8817468, 223.2307081, 256.8563066, 273.4110461, 286.520599],
    [124.9509045, 160.0638405, 206.1828711, 245.72141, 300.5807562, 311.2914522, 316.6114804, 337.6467061, 353.1548188, 383.4352239],
    [71.67030653, 101.3462293, 183.2348644, 234.5117401, 300.5807562, 321.9074219, 368.4211421, 373.4543741, 378.4591949, 440.7662838],
    [83.56019766, 130.8294293, 165.8759664, 217.5645032, 245.72141, 300.5807562, 327.1788737, 342.8422904, 381.4482916, 399.1606395, 430.5988776],
    [114.921522, 190.1377704, 242.8096145, 251.2625787, 304.6545405, 322.0508102, 344.9008091],
    [89.52878321, 133.8759691, 140.1743886, 165.2566473, 169.0023812, 190.1377704, 220.910219, 263.2729392, 292.9404065, 310.4770642],
    [102.2407086, 152.7387572, 171.496972, 196.323069, 214.7874746, 239.1757587, 269.2483042, 316.2759678],
    [89.52878321, 152.7387572, 190.1377704, 233.1048249, 269.2483042, 298.8088397, 327.8011521, 356.1701087, 383.8617625, 400.1296865],
    [95.88839333, 159.0037505, 251.2625787, 275.2031856, 298.8088397, 310.4770642, 322.0508102, 333.5265559, 343.7680499, 372.8697776, 410.8234541],
    [102.2407086, 146.4621441, 227.0161573, 263.2729392, 304.6545405, 322.0508102, 356.1701087, 383.8617625, 410.8234541]]

# Corresponding slope angles for each experiment
slope_angles = [
    [11, 15.4, 22, 24, 25, 28, 31, 32, 36, 41],
    [7, 14, 17.5, 23.5, 30, 32, 34, 36],
    [6, 13, 16, 17, 19, 22, 23, 24, 28],
    [7, 9, 10.5, 12, 13.5, 14.5, 17, 17.5, 18.5, 21, 22.8, 26],
    [6.5, 9, 10.5, 14, 16, 18, 19, 22, 23.5, 24.7],
    [10.5, 13.5, 17.5, 21, 26, 27, 27.5, 29.5, 31, 34],
    [6, 8.5, 15.5, 20, 26, 28, 32.5, 33, 33.5, 40],
    [7, 11, 14, 18.5, 21, 26, 28.5, 30, 33.8, 35.6, 38.9],
    [9, 15, 19.3, 20, 24.5, 26, 28],
    [7, 10.5, 11, 13, 13.3, 15, 17.5, 21, 23.5, 25],
    [8, 12, 13.5, 15.5, 17, 19, 21.5, 25.5],
    [7, 12, 15, 18.5, 21.5, 24, 26.5, 29, 31.5, 33],
    [7.5, 12.5, 20, 22, 24, 25, 26, 27, 27.9, 30.5, 34],
    [8, 11.5, 18, 21, 24.5, 26, 29, 31.5, 34]
]

fig, ax = plt.subplots(figsize=(18, 12))

#spacing specifications
bar_width = 1.0
gap = 1.5
x_offset = 0
bar_x = []
bar_heights = []
bar_labels = []
bar_colors = []

for exp_idx, (shears, slopes) in enumerate(zip(basal_shear_data, slope_angles)):
    x_vals = np.arange(len(shears)) + x_offset
    bar_x.extend(x_vals)
    bar_heights.extend(shears)
    bar_labels.extend([f"{s}°" for s in slopes])

    for slope, shear in zip(slopes, shears):
      bar_colors.append('lightblue')

    x_offset += len(shears) + gap

# Plot
ax.bar(bar_x, bar_heights, width=bar_width, color=bar_colors, edgecolor='black')

#slope angle labels above each bar
label_offset = -0.55
for x, h, label in zip(bar_x, bar_heights, bar_labels):
    ax.text(x + label_offset, h + 5, label,
            ha='center', va='bottom', fontsize=11.2,
            color='black', rotation=270, fontweight='bold')

# X-ticks
group_centers = []
x_offset = 0
for shear_group in basal_shear_data:
    group_len = len(shear_group)
    center = x_offset + group_len / 2 - 0.5
    group_centers.append(center)
    x_offset += group_len + gap

ax.set_xticks(group_centers)
ax.set_xticklabels([f'Exp {i}' for i in range(1, 15)],
                   rotation=45, fontweight='bold', fontsize=11)

ax.set_xlabel('Experiment Number', fontsize=13, fontweight='bold')
ax.set_ylabel('Basal Shear Stress (Pa)', fontsize=13, fontweight='bold')
ax.grid(True, axis='y', linestyle='--', alpha=0.4)

buffer = 1.0
ax.set_xlim(bar_x[0] - buffer, bar_x[-1] + buffer)

ax.tick_params(axis='y', labelsize=10)
for label in ax.get_yticklabels():
    label.set_fontweight('bold')

plt.tight_layout()
plt.savefig("shear_stress_critical_highlighted.png", dpi=300)
plt.show()

# %% [markdown]
# Following is the code for plotting scaled mean shear stress for each slope interval. Refer to Appendix B for scaling factor.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import FuncFormatter

#scaled shear stress values for 10m ice-dust mantle
scaled_shear_values = [
    # exp1 to exp14 scaled shear stress values for 10m ice-dust mantle
    [0.005840599524, 0.008128632878, 0.0114667994, 0.01245036832, 0.01293654434,
     0.01437086705, 0.01576584012, 0.0162214233, 0.01799303047, 0.02008342172],
    [0.003730365967, 0.00740517707, 0.009204592459, 0.01220585027, 0.01530545939,
     0.0162214233, 0.01711764392, 0.01799303047],
    [0.003895125355, 0.00838258356, 0.01027140597, 0.01089501683, 0.0121321037,
     0.01395958188, 0.01456049139, 0.01515697013, 0.01749496858],
    [0.00454131509, 0.005829352566, 0.006790810026, 0.00774761812, 0.008699121766,
     0.009330188747, 0.01089501683, 0.01120559082, 0.01182415778, 0.01335442445,
     0.01444065812, 0.01633591066],
    [0.004218380683, 0.005829352566, 0.006790810026, 0.009014998172, 0.01027140597,
     0.01151531233, 0.0121321037, 0.01395958188, 0.01485929598, 0.01557177168],
    [0.006790810026, 0.008699121766, 0.01120559082, 0.01335442445, 0.01633591066,
     0.01691801371, 0.01720714567, 0.01835036446, 0.01919319667, 0.02083887086],
    [0.003895125355, 0.005507947246, 0.009958416543, 0.01274520327, 0.01633591066,
     0.01749496858, 0.02002288816, 0.02029643337, 0.02056843451, 0.02395468934],
    [0.00454131509, 0.007110295073, 0.009014998172, 0.01182415778, 0.01335442445,
     0.01633591066, 0.01778146053, 0.01863273317, 0.02073088541, 0.02169351302,
     0.02340211291],
    [0.006245734893, 0.01033357448, 0.0131961747, 0.01365557493, 0.01655731198,
     0.01750276143, 0.01874460919],
    [0.004865694739, 0.007275867885, 0.007618173292, 0.008981339529, 0.01033357448,
     0.01200599016, 0.01430831192, 0.01592067427, 0.01687375349],
    [0.005556560249, 0.008301019414, 0.009320487607, 0.01066973201, 0.01167323232,
     0.01299868254, 0.01463306001, 0.01718891129],
    [0.004865694739, 0.008301019414, 0.01033357448, 0.01266874048, 0.01463306001,
     0.01623961085, 0.01781528, 0.01935707113, 0.02086205231, 0.02174617862],
    [0.005211325725, 0.00864150818, 0.01365557493, 0.01495669487, 0.01623961085,
     0.01687375349, 0.01750276143, 0.01812644326, 0.02026466182, 0.02232736164],
    [0.005556560249, 0.007959899135, 0.01233783463, 0.01430831192, 0.01655731198,
     0.01750276143, 0.01935707113, 0.02086205231, 0.02232736164]
]

# Corresponding slope angles
slope_angles = [
    [11, 15.4, 22, 24, 25, 28, 31, 32, 36, 41],
    [7, 14, 17.5, 23.5, 30, 32, 34, 36],
    [6, 13, 16, 17, 19, 22, 23, 24, 28],
    [7, 9, 10.5, 12, 13.5, 14.5, 17, 17.5, 18.5, 21, 22.8, 26],
    [6.5, 9, 10.5, 14, 16, 18, 19, 22, 23.5, 24.7],
    [10.5, 13.5, 17.5, 21, 26, 27, 27.5, 29.5, 31, 34],
    [6, 8.5, 15.5, 20, 26, 28, 32.5, 33, 33.5, 40],
    [7, 11, 14, 18.5, 21, 26, 28.5, 30, 33.8, 35.6, 38.9],
    [9, 15, 19.3, 20, 24.5, 26, 28],
    [7, 10.5, 11, 13, 15, 17.5, 21, 23.5, 25],
    [8, 12, 13.5, 15.5, 17, 19, 21.5, 25.5],
    [7, 12, 15, 18.5, 21.5, 24, 26.5, 29, 31.5, 33],
    [7.5, 12.5, 20, 22, 24, 25, 26, 27, 30.5, 34],
    [8, 11.5, 18, 21, 24.5, 26, 29, 31.5, 34]
]

# Flatten data for both 10m and 100m ice-dust mantle value. Values for 100m ice-dust mantle is got by multiplying the values of 10m ice-dust mantle with 10. Refer to Appendix B for further clarifications.
flat_slope = []
flat_shear = []
flat_shear_0_1 = []

for shear_list, slope_list in zip(scaled_shear_values, slope_angles):
    flat_slope.extend(slope_list)
    flat_shear.extend(shear_list)
    flat_shear_0_1.extend([v * 10 for v in shear_list])

# Create DataFrame
df = pd.DataFrame({
    'slope': flat_slope,
    'Scaled shear stress for 10 m ice-dust mantle': flat_shear,
    'Scaled shear stress for 100 m ice-dust mantle': flat_shear_0_1
})

# Define slope bins
bins = np.arange(0, 50, 5)
labels = [f'{bins[i]}–{bins[i+1]}' for i in range(len(bins)-1)]

df['slope_bin'] = pd.cut(df['slope'], bins=bins, labels=labels, right=False)

# Group by bins and average
grouped = df.groupby('slope_bin')[['Scaled shear stress for 10 m ice-dust mantle', 'Scaled shear stress for 100 m ice-dust mantle']].mean()

# Custom formatter
def log_formatter(y, _):
    exp = int(np.floor(np.log10(y))) if y != 0 else 0
    base = y / (10**exp)
    if np.isclose(base, 1.0):
        return rf'$10^{{{exp}}}$'
    else:
        return rf'${base:.1f}\times10^{{{exp}}}$'

# Plot
ax = grouped.plot(kind='bar', figsize=(8, 5), color=['skyblue', 'orange'], edgecolor='black')

# Format y-axis
ax.yaxis.set_major_formatter(FuncFormatter(log_formatter))
#horizontal lines
plt.axhline(y=10**-1.5, color='red', linestyle=':', linewidth=1.5, label=r'$10^{-1.5}$ MPa')
plt.axhline(y=10**-3.5, color='blue', linestyle=':', linewidth=1.5, label=r'$10^{-3.5}$ MPa')

# Labels and layout
plt.ylabel("Scaled shear stress (MPa)")
plt.xlabel("Slope angle(°)")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-d1638e5db756>:83: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby('slope_bin')[['Scaled shear stress for 10 m ice-dust mantle', 'Scaled shear stress for 100 m ice-dust mantle']].mean()

# %% [markdown]
# # Fititng a linear regression model for each experiemnt

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from matplotlib.font_manager import FontProperties

# Data. Refer to appendix B and C for computation of shear stress values starin rate values
experiment_data = {
    "EXP1": [(0.00299850075,229.0867771),(0.0229,265.0324159),(0.1311594203,325.2239537),
             (0.06793478261,290.0914583),(0.06739130435,331.0717607),
             (0.11352657,369.5349596)],
    "EXP2": [(0.006864988558,281.6204528),(0.01242236025,298.4741886),(0.04710144928,314.9646482),
             (0.02913043478,331.0717607)],
    "EXP3": [(0.3571428571,154.2395375),(0.3883928571,188.9938698),(0.9714285714,200.4683097),
             (1.035714286,223.2307081),(1.435714286,256.8563066),(2.017857143,267.9130416),
             (2.089285714,278.8882504)],
    "EXP4": [(0.04285714286,83.56019766),(0.1035714286,107.2600872),(0.443877551,124.9509045),
             (3.3,260.3),(1.285714286,160.0638405),(1.428571429,171.6754729),
             (1.06547619,200.4683097),(1.6875,206.1828711),(3.607142857,217.5645032),
             (2.547619048,245.72141),(0.7,160.7081094),(2,300.5807562)],
    "EXP5": [(0.01623376623,77.61820456),(0.06785714286,107.2600872),(0.8928571429,124.9509045),
             (1.116071429,165.8759664),(1.473214286,188.9938698),(1.06547619,211.8817468),
             (1.732142857,223.2307081),(3.660714286,256.8563066),(2.595238095,273.4110461),
             (1.564285714,286.520599)],
    "EXP6": [(0.001400560224,124.9509045),(0.01984126984,160.0638405),(0.0467032967,206.1828711),
             (0.1126373626,245.72141),(0.2225274725,300.5807562),(0.8642857143,311.2914522),
             (0.4678571429,316.6114804),(0.9928571429,337.6467061),(1.75,353.1548188),
             (0.8869047619,383.4352239)],
    "EXP7": [(0.006302521008,101.3462293),(0.08571428571,183.2348644),(0.4071428571,234.5117401),
             (1.857142857,300.5807562),(0.9107142857,321.9074219),(0.9702380952,368.4211421),(2.154761905,378.4591949),(1.692857143,390.7662838)],
    "EXP8": [(0.006802721088,83.56019766),(0.02232142857,130.8294293),(0.05952380952,165.8759664),
             (0.3,217.5645032),(0.4928571429,245.72141),(0.9214285714,300.5807562),
             (0.5912698413,327.1788737),(1.330357143,342.8422904),(1.491071429,381.4482916),
             (0.7857142857,399.1606395),(1.278571429,430.5988776)],
    "EXP9": [(0.05555555556,114.921522),(0.196969697,190.1377704),(1.755555556,242.8096145),
             (2.316666667,255.2625787),(1.683333333,304.6545405),(0.6,248.0508102),
             (2.5,320.9008091)],
    "EXP10": [(4,230.52878321),(0.06153846154,153.8759691),(3,220),
              (0.575,185.2566473),(2,217),(5.933333333,220.910219),
              (1.683333333,213.2729392),(5,250),(0.6757575758,220.4770642)],
    "EXP11": [(0.1,102.2407086),(0.2791666667,152.7387572),(0.75,184),
              (2.383333333,240),(1.093333333,214.7874746),(1.558333333,239.1757587),
              (1.741666667,269.2483042),(1.042857143,255)],
    "EXP12": [(0.01111111111,89.52878321),(0.08333333333,152.7387572),(0.5555555556,190.1377704),
              (0.6,233.1048249),(0.9733333333,269.2483042),(0.5888888889,298.8088397),
              (1.944444444,327.8011521),(0.9047619048,356.1701087),(0.9166666667,383.8617625),
              (1.916666667,400.1296865)],
    "EXP13": [(0.04166666667,119),(0.08888888889,170),(0.325,251.2625787),
              (0.875,275.2031856),(2.033333333,298.8088397),(1.488888889,310.4770642),
              (0.9333333333,322.0508102),(0.9866666667,333.5265559),(2.2,343.7680499),
              (1.866666667,365),(1.66,325)],
    "EXP14": [(0.05,102.2407086),(0.06851851852,146.4621441),(0.2875,227.0161573),
              (0.6055555556,263.2729392),(1.433333333,304.6545405),(1.208333333,322.0508102),
              (1.766666667,356.1701087),(1.173333333,383.8617625),(1.246666667,410.8234541)],
}

# Setup figure and grid
fig = plt.figure(figsize=(20, 16))
gs = fig.add_gridspec(4, 4)

# Subplots
axes = []
for i in range(3):
    for j in range(4):
        axes.append(fig.add_subplot(gs[i, j]))
axes.append(fig.add_subplot(gs[3, 1]))  # EXP13
axes.append(fig.add_subplot(gs[3, 2]))  # EXP14

legend_font = FontProperties(size=12.8,weight='bold')
# Fit and plot with R²
rheology_params = {}
for i, (exp, data) in enumerate(experiment_data.items()):
    ax = axes[i]
    data = np.array(data)
    strain_rate = data[:, 0].reshape(-1, 1)
    shear_stress = data[:, 1]

    model = LinearRegression()
    model.fit(strain_rate, shear_stress)
    predictions = model.predict(strain_rate)

    η = model.coef_[0]
    τc = model.intercept_
    R2 = r2_score(shear_stress,predictions)

    rheology_params[exp] = (τc, η, R2)

    ax.scatter(strain_rate, shear_stress,color='blue', label='Data')
    ax.plot(strain_rate, predictions, color='red',
            label=f'τ = {τc:.1f} + {η:.1f}·γ̇\nR² = {R2:.2f}')

    ax.set_title(exp, fontsize=18, fontweight='bold')
    ax.legend(
    fontsize=14,
    prop=legend_font,
    loc='lower right'
)
    ax.tick_params(labelsize=14)
    ax.set_xlabel('', fontsize=14,fontweight='bold')
    ax.set_ylabel('', fontsize=14, fontweight='bold')

    #ticks and tick labels
    for label in (ax.get_xticklabels() + ax.get_yticklabels()):
        label.set_fontweight('bold')

#Hide unused subplot
if len(axes) > len(experiment_data):
    for j in range(len(experiment_data), len(axes)):
        axes[j].axis('off')

# Shared axis label
plt.subplots_adjust(hspace=0.5, wspace=0.3)
fig.text(0.55, 0.05, 'Strain rate (γ̇)',ha='center', fontsize=20, fontweight='bold')
fig.text(0.06, 0.5, 'Shear stress (Pa)', va='center', rotation='vertical', fontsize=20, fontweight='bold')

plt.tight_layout(rect=[0.08, 0.06, 1, 1])
plt.savefig("reg_fit_eff.viscosity.png",dpi=300)
plt.show()

# printing output rheology parameters
print("Rheological Parameters (τ = τc + η·γ̇):\n")
for exp, (tau_c, eta, r2) in rheology_params.items():
    print(f"{exp}: τc = {tau_c:.2f} Pa, η = {eta:.2f} Pa·s, R² = {r2:.3f}")
# Out:
# Rheological Parameters (τ = τc + η·γ̇):
#
# EXP1: τc = 241.65 Pa, η = 887.17 Pa·s, R² = 0.759
# EXP2: τc = 286.20 Pa, η = 851.42 Pa·s, R² = 0.527
# EXP3: τc = 150.27 Pa, η = 62.53 Pa·s, R² = 0.914
# EXP4: τc = 119.57 Pa, η = 44.16 Pa·s, R² = 0.645
# EXP5: τc = 116.19 Pa, η = 53.21 Pa·s, R² = 0.657
# EXP6: τc = 211.42 Pa, η = 116.57 Pa·s, R² = 0.608
# EXP7: τc = 179.32 Pa, η = 104.47 Pa·s, R² = 0.687
# EXP8: τc = 150.62 Pa, η = 187.98 Pa·s, R² = 0.791
# EXP9: τc = 166.02 Pa, η = 56.50 Pa·s, R² = 0.666
# EXP10: τc = 187.83 Pa, η = 9.63 Pa·s, R² = 0.521
# EXP11: τc = 137.93 Pa, η = 61.88 Pa·s, R² = 0.682
# EXP12: τc = 164.54 Pa, η = 124.33 Pa·s, R² = 0.626
# EXP13: τc = 191.38 Pa, η = 80.72 Pa·s, R² = 0.669
# EXP14: τc = 152.71 Pa, η = 145.69 Pa·s, R² = 0.765
